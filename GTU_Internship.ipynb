# %% [markdown]
# <a href="https://colab.research.google.com/github/kovvddd00/GTU-Summer-Internship/blob/main/GTU_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LIST METHODS IN PYTHON

# Original List
list1 = ["j", "d", "w", "f", "n", "22"]
print("Original List:", list1)

print("\n1. append()")
list2 = list1.copy()
list2.append("k")
print(list2)

print("\n2. extend()")
list2 = list1.copy()
list2.extend(["a", "b", "c"])
print(list2)

print("\n3. insert()")
list2 = list1.copy()
list2.insert(2, "x")
print(list2)

print("\n4. remove()")
list2 = list1.copy()
list2.remove("22")
print(list2)

print("\n5. pop()")
list2 = list1.copy()
removed = list2.pop()
print("Removed Element:", removed)
print("Updated List:", list2)

print("\n6. clear()")
list2 = list1.copy()
list2.clear()
print(list2)

print("\n7. del")
list2 = list1.copy()
print("Before del:", list2)
del list2
print("List deleted successfully.")

print("\n8. index()")
print("Index of 'w' =", list1.index("w"))

print("\n9. count()")
print("Count of '22' =", list1.count("22"))

print("\n10. sort()")
list2 = list1.copy()
list2.sort()
print(list2)

print("\n11. reverse()")
list2 = list1.copy()
list2.reverse()
print(list2)
# Out:
# Original List: ['j', 'd', 'w', 'f', 'n', '22']
#
# 1. append()
# ['j', 'd', 'w', 'f', 'n', '22', 'k']
#
# 2. extend()
# ['j', 'd', 'w', 'f', 'n', '22', 'a', 'b', 'c']
#
# 3. insert()
# ['j', 'd', 'x', 'w', 'f', 'n', '22']
#
# 4. remove()
# ['j', 'd', 'w', 'f', 'n']
#
# 5. pop()
# Removed Element: 22
# Updated List: ['j', 'd', 'w', 'f', 'n']
#
# 6. clear()
# []
#
# 7. del
# Before del: ['j', 'd', 'w', 'f', 'n', '22']
# List deleted successfully.
#
# 8. index()
# Index of 'w' = 2
#
# 9. count()
# Count of '22' = 1
#
# 10. sort()
# ['22', 'd', 'f', 'j', 'n', 'w']
#
# 11. reverse()
# ['22', 'n', 'f', 'w', 'd', 'j']

# %%
keys_list = ['names', 'rollno', 'stream']
print("1", type(keys_list))

names_list = ['GJ', 'MH', 'RJ']
roll_list = [1,11,111]

dictb = dict.fromkeys(keys_list)
print("2", dictb)

dictb['names'] = names_list
dictb['rollno'] = roll_list
dictb['stream'] = ['DS', 'CS', 'EC']
dictb['city'] = [1,2,3]
dictb.update({'AQI': [101,200,300]})
print("3", dictb)

print("4", dictb.items())
print("5", dictb.keys())
print("6", dictb.values())
# Out:
# 1 <class 'list'>
# 2 {'names': None, 'rollno': None, 'stream': None}
# 3 {'names': ['GJ', 'MH', 'RJ'], 'rollno': [1, 11, 111], 'stream': ['DS', 'CS', 'EC'], 'city': [1, 2, 3], 'AQI': [101, 200, 300]}
# 4 dict_items([('names', ['GJ', 'MH', 'RJ']), ('rollno', [1, 11, 111]), ('stream', ['DS', 'CS', 'EC']), ('city', [1, 2, 3]), ('AQI', [101, 200, 300])])
# 5 dict_keys(['names', 'rollno', 'stream', 'city', 'AQI'])
# 6 dict_values([['GJ', 'MH', 'RJ'], [1, 11, 111], ['DS', 'CS', 'EC'], [1, 2, 3], [101, 200, 300]])

# %%
my_tuple = (1,2,3,4)
print(my_tuple)
# Out:
# (1, 2, 3, 4)
